# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization
from keras.utils import to_categorical
import tensorflow as tf 
import pcap_processor
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/Users/kyletopasna/Documents/hunter/ISCX CIC/CIC-IDS-2017/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
# Out:
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning:
#
# Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
data.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22             166                   1
# 1              60148              83                   1
# 2                123           99947                   1
# 3                123           37017                   1
# 4                  0       111161336                 147
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            0
# 1                        2                            0
# 2                        1                           48
# 3                        1                           48
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       0
# 1                             0                       0
# 2                            48                      48
# ...

# %%
data.shape
# Out:
# (288602, 79)

# %%
data.dtypes
# Out:
#  Destination Port                 int64
#  Flow Duration                    int64
#  Total Fwd Packets                int64
#  Total Backward Packets           int64
# Total Length of Fwd Packets       int64
#  Total Length of Bwd Packets      int64
#  Fwd Packet Length Max            int64
#  Fwd Packet Length Min            int64
#  Fwd Packet Length Mean         float64
#  Fwd Packet Length Std          float64
# Bwd Packet Length Max             int64
#  Bwd Packet Length Min            int64
#  Bwd Packet Length Mean         float64
#  Bwd Packet Length Std          float64
# Flow Bytes/s                     object
#  Flow Packets/s                  object
#  Flow IAT Mean                  float64
#  Flow IAT Std                   float64
#  Flow IAT Max                     int64
#  Flow IAT Min                     int64
# Fwd IAT Total                     int64
#  Fwd IAT Mean                   float64
#  Fwd IAT Std                    float64
# ...

# %%
object_dtypes_from_data = data.select_dtypes(include="object")
print(object_dtypes_from_data)
# Out:
#        Flow Bytes/s  Flow Packets/s   Label
# 0                 0     12048.19277  BENIGN
# 1                 0     36144.57831  BENIGN
# 2       960.5090698     20.01060562  BENIGN
# 3       2593.403031     54.02922981  BENIGN
# 4                 0     1.322402242  BENIGN
# 5       2499.544354     52.07384071  BENIGN
# 6       26690.74004     84.71569941  BENIGN
# 7       23895.55511     84.13927855  BENIGN
# 8       16207.45543     972.4473258  BENIGN
# 9       21.24061803      0.27742848  BENIGN
# 10      11.02565352     0.260448508  BENIGN
# 11      222.0304237     0.304812388  BENIGN
# 12      14348.26452     14.02492652  BENIGN
# 13      3389.167699      65.1763019  BENIGN
# 14      1089005.236     20942.40838  BENIGN
# 15      4460.478846     65.59527714  BENIGN
# 16      1064935.065     25974.02597  BENIGN
# 17      1433962.264      25157.2327  BENIGN
# 18      6.643969083     0.099163718  BENIGN
# 19      4852.777231     65.57807069  BENIGN
# ...

# %%
print(data.columns)
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
data.loc[:,["Flow Bytes/s", " Flow Packets/s"]] = data.loc[:,["Flow Bytes/s", " Flow Packets/s"]].apply(pd.to_numeric, errors='coerce')

# %%
object_dtypes_from_data = data.select_dtypes(include="object")
print(object_dtypes_from_data)
# Out:
#          Label
# 0       BENIGN
# 1       BENIGN
# 2       BENIGN
# 3       BENIGN
# 4       BENIGN
# 5       BENIGN
# 6       BENIGN
# 7       BENIGN
# 8       BENIGN
# 9       BENIGN
# 10      BENIGN
# 11      BENIGN
# 12      BENIGN
# 13      BENIGN
# 14      BENIGN
# 15      BENIGN
# 16      BENIGN
# 17      BENIGN
# 18      BENIGN
# 19      BENIGN
# 20      BENIGN
# 21      BENIGN
# 22      BENIGN
# 23      BENIGN
# 24      BENIGN
# 25      BENIGN
# 26      BENIGN
# 27      BENIGN
# 28      BENIGN
# 29      BENIGN
# ...        ...
# 288572  BENIGN
# 288573  BENIGN
# 288574  BENIGN
# 288575  BENIGN
# 288576  BENIGN
# 288577  BENIGN
# 288578  BENIGN
# 288579  BENIGN
# 288580  BENIGN
# 288581  BENIGN
# 288582  BENIGN
# 288583  BENIGN
# 288584  BENIGN
# 288585  BENIGN
# 288586  BENIGN
# 288587  BENIGN
# 288588  BENIGN
# 288589  BENIGN
# 288590  BENIGN
# 288591  BENIGN
# 288592  BENIGN
# 288593  BENIGN
# 288594  BENIGN
# 288595  BENIGN
# 288596  BENIGN
# 288597  BENIGN
# ...

# %%
data_boolean_isna = data.isna()
data_boolean_isna.
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 0                   False           False               False
# 1                   False           False               False
# 2                   False           False               False
# 3                   False           False               False
# 4                   False           False               False
# 5                   False           False               False
# 6                   False           False               False
# 7                   False           False               False
# 8                   False           False               False
# 9                   False           False               False
# 10                  False           False               False
# 11                  False           False               False
# 12                  False           False               False
# 13                  False           False               False
# ...

# %%
nan_rows = data[data.isnull().any(1)]
nan_rows
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 5676                48490               0                   2
# 6180                53661               0                   2
# 7327                   22               0                   1
# 8790                48640               0                   2
# 16096               44904               0                   2
# 18639               52374               0                   2
# 19262                  80               0                   1
# 27891                 443               0                   1
# 35324               60789               0                   2
# 36612                 443               0                   2
# 37273               53335               0                   1
# 37817                 389               0                   2
# 37821               47841               0                   2
# 38168               40884               0                   2
# ...

# %%
data.loc[5676]
# Out:
#  Destination Port                 48490
#  Flow Duration                        0
#  Total Fwd Packets                    2
#  Total Backward Packets               0
# Total Length of Fwd Packets          37
#  Total Length of Bwd Packets          0
#  Fwd Packet Length Max               31
#  Fwd Packet Length Min                6
#  Fwd Packet Length Mean            18.5
#  Fwd Packet Length Std          17.6777
# Bwd Packet Length Max                 0
#  Bwd Packet Length Min                0
#  Bwd Packet Length Mean               0
#  Bwd Packet Length Std                0
# Flow Bytes/s                        NaN
#  Flow Packets/s                     NaN
#  Flow IAT Mean                        0
#  Flow IAT Std                         0
#  Flow IAT Max                         0
#  Flow IAT Min                         0
# Fwd IAT Total                         0
#  Fwd IAT Mean                         0
#  Fwd IAT Std                          0
# ...

# %%
# Grab y_labels and remove from data
y_labels = data[" Label"]
data = data.drop(labels=" Label", axis=1)
data.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
y_labels.value_counts()
# Out:
# BENIGN          288566
# Infiltration        36
# Name:  Label, dtype: int64

# %%
data_cleaned = data.apply(lambda x: x.fillna(x.mean()),axis=0)
nan_rows = data_cleaned[data_cleaned.isnull().any(1)]
nan_rows
# Out:
# Empty DataFrame
# ...

# %%
#one hot encode labels
y_labels_as_int_list = []
for label in y_labels:
    if label == "Infiltration":
        y_labels_as_int_list.append(1)
    else:
        y_labels_as_int_list.append(0)
y_labels_encoded = to_categorical(y_labels_as_int_list)
# Out:
# (array([ 66383,  68410,  72581,  73090,  73634,  75039,  77445,  77580,
#          78192,  82330,  82485,  83696,  83861,  85564,  85630,  87264,
#          87271,  88333, 115196, 121140, 126139, 134452, 139341, 144687,
#         150840, 160013, 166343, 172340, 176018, 184772, 190372, 197642,
#         207900, 213243, 220906, 224706]),)

# %%
nn_input_dim = data.shape[1]
nn_input_dim
# Out:
# 78

# %%
neural_network = Sequential()
neural_network.add(Dense(128, input_dim=nn_input_dim, activation="relu"))
neural_network.add(BatchNormalization())
neural_network.add(Dense(256, activation="relu"))
neural_network.add(BatchNormalization())
neural_network.add(Dense(512, activation="relu"))
neural_network.add(BatchNormalization())
neural_network.add(Dense(2))
neural_network.add(Activation(tf.nn.softmax))

# %%
neural_network.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
neural_network.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_22 (Dense)             (None, 128)               10112
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               33024
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               131584
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 1026
# ...

# %%
neural_network.fit(data, y_labels_encoded, epochs=100, batch_size=100)
# Out:
# Epoch 1/100
# 288602/288602 [==============================] - 67s 234us/step - loss: 0.0122 - acc: 0.9972
# Epoch 2/100
# 288602/288602 [==============================] - 63s 217us/step - loss: 0.0013 - acc: 0.9999
# Epoch 3/100
# 288602/288602 [==============================] - 63s 218us/step - loss: 0.0013 - acc: 0.9999
# Epoch 4/100
# 288602/288602 [==============================] - 66s 227us/step - loss: 0.0013 - acc: 0.9999
# Epoch 5/100
# 288602/288602 [==============================] - 66s 230us/step - loss: 0.0013 - acc: 0.99991s - los
# Epoch 6/100
# 288602/288602 [==============================] - 58s 202us/step - loss: 0.0013 - acc: 0.9999
# Epoch 7/100
# 288602/288602 [==============================] - 59s 203us/step - loss: 0.0013 - acc: 0.9999
# Epoch 8/100
#  29500/288602 [==>...........................] - ETA: 1:00 - loss: 0.0011 - acc: 0.9999
# ---------------------------------------------------------------------------
# ...

# %%
incorrects = np.nonzero(neural_network.predict(data).reshape((-1,)) != y_labels_encoded)
# Out:
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning:
#
# elementwise != comparison failed; this will raise an error in the future.

# %%
incorrects
# Out:
# (array([0]),)

# %%
print(incorrects)
# Out:
# (array([0]),)
